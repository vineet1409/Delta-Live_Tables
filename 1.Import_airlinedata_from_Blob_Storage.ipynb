# %% [markdown]
# ### This notebook will get the Airline Data from the Azure Blob Storage and stores in the Table in the Databricks Environment

# %% [markdown]
# ### Step 1: Set the data location and type
#
# To get started, we need to set the location and type of the file.

# %%
# %python
adls_storage_name = "storagedbricks"
adls_storage_access_key = "/EUcMUvVI1jbpwl4WQBYcYHAhWNRRvXDHnVzotPTT4cumAznNhkc6Fjlcnju0YD3WSLLMopC37zL+AStmRHAHQ=="
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
file_location = "wasbs://airlines-data@storagedbricks.blob.core.windows.net/airport"
file_type = "csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
spark.conf.set(
  "fs.azure.account.key."+adls_storage_name+".blob.core.windows.net", adls_storage_access_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 2: Read all the airline data present under the folder airport
#
# Now that we have specified our file metadata, we can create a DataFrame. Notice that we use an *option* to specify that we want to infer the schema from the file. We can also explicitly set this to a particular schema if we have one already.
#
# First, let's create a DataFrame in Python.

# %%
# %python
df_air = spark.read.format(file_type).option("inferSchema", "true").option("header", "true").load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Query the data
#
# Now that we have created our DataFrame, we can query it. For instance, you can identify particular columns to select and display.

# %%
# %python
display(df_air)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MONTH</th><th>DAY_OF_MONTH</th><th>DAY_OF_WEEK</th><th>OP_UNIQUE_CARRIER</th><th>TAIL_NUM</th><th>OP_CARRIER_FL_NUM</th><th>ORIGIN_AIRPORT_ID</th><th>ORIGIN</th><th>ORIGIN_CITY_NAME</th><th>DEST_AIRPORT_ID</th><th>DEST</th><th>DEST_CITY_NAME</th><th>CRS_DEP_TIME</th><th>DEP_TIME</th><th>DEP_DELAY_NEW</th><th>DEP_DEL15</th><th>DEP_TIME_BLK</th><th>CRS_ARR_TIME</th><th>ARR_TIME</th><th>ARR_DELAY_NEW</th><th>ARR_TIME_BLK</th><th>CANCELLED</th><th>CANCELLATION_CODE</th><th>CRS_ELAPSED_TIME</th><th>ACTUAL_ELAPSED_TIME</th><th>DISTANCE</th><th>DISTANCE_GROUP</th><th>CARRIER_DELAY</th><th>WEATHER_DELAY</th><th>NAS_DELAY</th><th>SECURITY_DELAY</th><th>LATE_AIRCRAFT_DELAY</th><th>_c32</th></tr></thead><tbody><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N269WN</td><td>1562</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13204</td><td>MCO</td><td>Orlando, FL</td><td>1020</td><td>1032</td><td>12.0</td><td>0.0</td><td>1000-1059</td><td>1125</td><td>1132</td><td>7.0</td><td>1100-1159</td><td>0.0</td><td>null</td><td>65.0</td><td>60.0</td><td>177.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N743SW</td><td>2378</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13204</td><td>MCO</td><td>Orlando, FL</td><td>1910</td><td>1931</td><td>21.0</td><td>1.0</td><td>1900-1959</td><td>2020</td><td>2116</td><td>56.0</td><td>2000-2059</td><td>0.0</td><td>null</td><td>70.0</td><td>105.0</td><td>177.0</td><td>1</td><td>21.0</td><td>0.0</td><td>35.0</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N435WN</td><td>400</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13232</td><td>MDW</td><td>Chicago, IL</td><td>1955</td><td>2044</td><td>49.0</td><td>1.0</td><td>1900-1959</td><td>2205</td><td>2304</td><td>59.0</td><td>2200-2259</td><td>0.0</td><td>null</td><td>190.0</td><td>200.0</td><td>1167.0</td><td>5</td><td>6.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>43.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N204WN</td><td>606</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13232</td><td>MDW</td><td>Chicago, IL</td><td>1705</td><td>1711</td><td>6.0</td><td>0.0</td><td>1700-1759</td><td>1920</td><td>1955</td><td>35.0</td><td>1900-1959</td><td>0.0</td><td>null</td><td>195.0</td><td>224.0</td><td>1167.0</td><td>5</td><td>6.0</td><td>0.0</td><td>29.0</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N8718Q</td><td>1741</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13232</td><td>MDW</td><td>Chicago, IL</td><td>640</td><td>638</td><td>0.0</td><td>0.0</td><td>0600-0659</td><td>855</td><td>850</td><td>0.0</td><td>0800-0859</td><td>0.0</td><td>null</td><td>195.0</td><td>192.0</td><td>1167.0</td><td>5</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N7837A</td><td>2131</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13342</td><td>MKE</td><td>Milwaukee, WI</td><td>1655</td><td>1705</td><td>10.0</td><td>0.0</td><td>1600-1659</td><td>1920</td><td>2032</td><td>72.0</td><td>1900-1959</td><td>0.0</td><td>null</td><td>205.0</td><td>267.0</td><td>1243.0</td><td>5</td><td>10.0</td><td>0.0</td><td>62.0</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N919WN</td><td>1984</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13495</td><td>MSY</td><td>New Orleans, LA</td><td>1725</td><td>1730</td><td>5.0</td><td>0.0</td><td>1700-1759</td><td>1840</td><td>1932</td><td>52.0</td><td>1800-1859</td><td>0.0</td><td>null</td><td>135.0</td><td>182.0</td><td>674.0</td><td>3</td><td>0.0</td><td>0.0</td><td>52.0</td><td>0.0</td><td ...

# %% [markdown]
# ### Step 4: Create a temporary view or table for analysing the data
#
# If you want to query this data as a table, you can simply register it as a *view* or a table.

# %%
# %python
df_air.createOrReplaceTempView("airlineTemp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# We can query this view using Spark SQL. For instance, we can perform a simple aggregation. Notice how we can use `%sql` to query the view from SQL.

# %%
# %sql
SELECT * FROM airlineTemp WHERE TAIL_NUM = 'N743SW'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MONTH</th><th>DAY_OF_MONTH</th><th>DAY_OF_WEEK</th><th>OP_UNIQUE_CARRIER</th><th>TAIL_NUM</th><th>OP_CARRIER_FL_NUM</th><th>ORIGIN_AIRPORT_ID</th><th>ORIGIN</th><th>ORIGIN_CITY_NAME</th><th>DEST_AIRPORT_ID</th><th>DEST</th><th>DEST_CITY_NAME</th><th>CRS_DEP_TIME</th><th>DEP_TIME</th><th>DEP_DELAY_NEW</th><th>DEP_DEL15</th><th>DEP_TIME_BLK</th><th>CRS_ARR_TIME</th><th>ARR_TIME</th><th>ARR_DELAY_NEW</th><th>ARR_TIME_BLK</th><th>CANCELLED</th><th>CANCELLATION_CODE</th><th>CRS_ELAPSED_TIME</th><th>ACTUAL_ELAPSED_TIME</th><th>DISTANCE</th><th>DISTANCE_GROUP</th><th>CARRIER_DELAY</th><th>WEATHER_DELAY</th><th>NAS_DELAY</th><th>SECURITY_DELAY</th><th>LATE_AIRCRAFT_DELAY</th><th>_c32</th></tr></thead><tbody><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N743SW</td><td>2378</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13204</td><td>MCO</td><td>Orlando, FL</td><td>1910</td><td>1931</td><td>21.0</td><td>1.0</td><td>1900-1959</td><td>2020</td><td>2116</td><td>56.0</td><td>2000-2059</td><td>0.0</td><td>null</td><td>70.0</td><td>105.0</td><td>177.0</td><td>1</td><td>21.0</td><td>0.0</td><td>35.0</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N743SW</td><td>172</td><td>13495</td><td>MSY</td><td>New Orleans, LA</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>1055</td><td>1125</td><td>30.0</td><td>1.0</td><td>1000-1059</td><td>1350</td><td>1401</td><td>11.0</td><td>1300-1359</td><td>0.0</td><td>null</td><td>115.0</td><td>96.0</td><td>674.0</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE airlineReporting
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Step 5: Create a Permanent Table
#
# Since this table is registered as a temp view, it will be available only to this notebook. If you'd like other users to be able to query this table, we have to create a permanent table from the DataFrame as below.

# %%
# %python
df_air.write.format("csv").saveAsTable("airlineReporting")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
Select * from airlineReporting
WHERE TAIL_NUM = 'N743SW'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MONTH</th><th>DAY_OF_MONTH</th><th>DAY_OF_WEEK</th><th>OP_UNIQUE_CARRIER</th><th>TAIL_NUM</th><th>OP_CARRIER_FL_NUM</th><th>ORIGIN_AIRPORT_ID</th><th>ORIGIN</th><th>ORIGIN_CITY_NAME</th><th>DEST_AIRPORT_ID</th><th>DEST</th><th>DEST_CITY_NAME</th><th>CRS_DEP_TIME</th><th>DEP_TIME</th><th>DEP_DELAY_NEW</th><th>DEP_DEL15</th><th>DEP_TIME_BLK</th><th>CRS_ARR_TIME</th><th>ARR_TIME</th><th>ARR_DELAY_NEW</th><th>ARR_TIME_BLK</th><th>CANCELLED</th><th>CANCELLATION_CODE</th><th>CRS_ELAPSED_TIME</th><th>ACTUAL_ELAPSED_TIME</th><th>DISTANCE</th><th>DISTANCE_GROUP</th><th>CARRIER_DELAY</th><th>WEATHER_DELAY</th><th>NAS_DELAY</th><th>SECURITY_DELAY</th><th>LATE_AIRCRAFT_DELAY</th><th>_c32</th></tr></thead><tbody><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N743SW</td><td>2378</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>13204</td><td>MCO</td><td>Orlando, FL</td><td>1910</td><td>1931</td><td>21.0</td><td>1.0</td><td>1900-1959</td><td>2020</td><td>2116</td><td>56.0</td><td>2000-2059</td><td>0.0</td><td>null</td><td>70.0</td><td>105.0</td><td>177.0</td><td>1</td><td>21.0</td><td>0.0</td><td>35.0</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>2</td><td>27</td><td>3</td><td>WN</td><td>N743SW</td><td>172</td><td>13495</td><td>MSY</td><td>New Orleans, LA</td><td>11697</td><td>FLL</td><td>Fort Lauderdale, FL</td><td>1055</td><td>1125</td><td>30.0</td><td>1.0</td><td>1000-1059</td><td>1350</td><td>1401</td><td>11.0</td><td>1300-1359</td><td>0.0</td><td>null</td><td>115.0</td><td>96.0</td><td>674.0</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
Select count(1) from airlineReporting
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4893</td></tr></tbody></table></div>

# %% [markdown]
# #### This table will persist across cluster restarts and allow various users across different notebooks to query this data.
